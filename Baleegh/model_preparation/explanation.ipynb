# %%
import shap
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %%
# load the model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("AbdulmohsenA/Faseeh")
model = AutoModelForSeq2SeqLM.from_pretrained("AbdulmohsenA/Faseeh")

# define the input sentences we want to translate
data = [
    "Transformers have rapidly become the model of choice for NLP problems, replacing older recurrent neural network models"
]

# %%
# load the model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-ar")
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-ar")

# define the input sentences we want to translate
data = [
    "They said this is but our current life, and we will not be alive again"
]

# %%
explainer = shap.Explainer(model, tokenizer)

# explainers are callable, just like models
shap_values = explainer(data, fixed_context=1)

# %%
shap_values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 shap_values
#
# NameError: name 'shap_values' is not defined

# %%
shap.plots.text(shap_values)
# Out:
# <br>
# <hr style="height: 1px; background-color: #fff; border: none; margin-top: 18px; margin-bottom: 18px; border-top: 1px dashed #ccc;"">
# <div align="center" style="margin-top: -35px;"><div style="display: inline-block; background: #fff; padding: 5px; color: #999; font-family: monospace">[0]</div>
# </div>
#             <div align='center'>
# <script>
#     document._hover_glafqubekximcwdrbtqs = '_tp_glafqubekximcwdrbtqs_output_0';
#     document._zoom_glafqubekximcwdrbtqs = undefined;
#     function _output_onclick_glafqubekximcwdrbtqs(i) {
#         var next_id = undefined;
#
#         if (document._zoom_glafqubekximcwdrbtqs !== undefined) {
#             document.getElementById(document._zoom_glafqubekximcwdrbtqs+ '_zoom').style.display = 'none';
#
#             if (document._zoom_glafqubekximcwdrbtqs === '_tp_glafqubekximcwdrbtqs_output_' + i) {
#                 document.getElementById(document._zoom_glafqubekximcwdrbtqs).style.display = 'block';
#                 document.getElementById(document._zoom_glafqubekximcwdrbtqs+'_name').style.borderBottom = '3px solid #000000';
#             } else {
#                 document.getElementById(document._zoom_glafqubekximcwdrbtqs).style.display = 'none';
#                 document.getElementById(document._zoom_glafqubekximcwdrbtqs+'_name').style.borderBottom = 'none';
#             }
#         }
#         if (document._zoom_glafqubekximcwdrbtqs !== '_tp_glafqubekximcwdrbtqs_output_' + i) {
#             next_id = '_tp_glafqubekximcwdrbtqs_output_' + i;
#             document.getElementById(next_id).style.display = 'none';
#             document.getElementById(next_id + '_zoom').style.display = 'block';
#             document.getElementById(next_id+'_name').style.borderBottom = '3px solid #000000';
#         }
#         document._zoom_glafqubekximcwdrbtqs = next_id;
#     }
#     function _output_onmouseover_glafqubekximcwdrbtqs(i, el) {
#         if (document._zoom_glafqubekximcwdrbtqs !== undefined) { return; }
#         if (document._hover_glafqubekximcwdrbtqs !== undefined) {
#             document.getElementById(document._hover_glafqubekximcwdrbtqs + '_name').style.borderBottom = 'none';
#             document.getElementById(document._hover_glafqubekximcwdrbtqs).style.display = 'none';
#         }
#         document.getElementById('_tp_glafqubekximcwdrbtqs_output_' + i).style.display = 'block';
#         el.style.borderBottom = '3px solid #000000';
#         document._hover_glafqubekximcwdrbtqs = '_tp_glafqubekximcwdrbtqs_output_' + i;
#     }
# </script>
# <div style="color: rgb(120,120,120); font-size: 12px;">outputs</div>
# <div style="display: inline; border-bottom: 3px solid #000000; background: rgba(30.0, 136.0, 229.0, 0.10924935630817977); border-radius: 3px; padding: 0px" id="_tp_glafqubekximcwdrbtqs_output_0_name"
#     onclick="_output_onclick_glafqubekximcwdrbtqs(0)"
#     onmouseover="_output_onmouseover_glafqubekximcwdrbtqs(0, this);">قالوا</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.621628045157457); border-radius: 3px; padding: 0px" id="_tp_glafqubekximcwdrbtqs_output_1_name"
#     onclick="_output_onclick_glafqubekximcwdrbtqs(1)"
#     onmouseover="_output_onmouseover_glafqubekximcwdrbtqs(1, this);">أن</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.2826698356110118); border-radius: 3px; padding: 0px" id="_tp_glafqubekximcwdrbtqs_output_2_name"
#     onclick="_output_onclick_glafqubekximcwdrbtqs(2)"
#     onmouseover="_output_onmouseover_glafqubekximcwdrbtqs(2, this);">هذا</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.9605862547039017); border-radius: 3px; padding: 0px" id="_tp_glafqubekximcwdrbtqs_output_3_name"
#     onclick="_output_onclick_glafqubekximcwdrbtqs(3)"
#     onmouseover="_output_onmouseover_glafqubekximcwdrbtqs(3, this);">هو</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 1.0); border-radius: 3px; padding: 0px" id="_tp_glafqubekximcwdrbtqs_output_4_name"
#     onclick="_output_onclick_glafqubekximcwdrbtqs(4)"
#     onmouseover="_output_onmouseover_glafqubekximcwdrbtqs(4, this);">فقط</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.889641513170925); border-radius: 3px; padding: 0px" id="_tp_glafqubekximcwdrbtqs_output_5_name"
#     onclick="_output_onclick_glafqubekximcwdrbtqs(5)"
#     onmouseover="_output_onmouseover_glafqubekximcwdrbtqs(5, this);">حياتنا</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.13289760348583876); border-radius: 3px; padding: 0px" id="_tp_glafqubekximcwdrbtqs_output_6_name"
#     onclick="_output_onclick_glafqubekximcwdrbtqs(6)"
#     onmouseover="_output_onmouseover_glafqubekximcwdrbtqs(6, this);">الحالية</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.731986531986532); border-radius: 3px; padding: 0px" id="_tp_glafqubekximcwdrbtqs_output_7_name"
#     onclick="_output_onclick_glafqubekximcwdrbtqs(7)"
#     onmouseover="_output_onmouseover_glafqubekximcwdrbtqs(7, this);">،</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.5428005545652604); border-radius: 3px; padding: 0px" id="_tp_glafqubekximcwdrbtqs_output_8_name"
#     onclick="_output_onclick_glafqubekximcwdrbtqs(8)"
#     onmouseover="_output_onmouseover_glafqubekximcwdrbtqs(8, this);">ونحن</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.6295107942166767); border-radius: 3px; padding: 0px" id="_tp_glafqubekximcwdrbtqs_output_9_name"
#     onclick="_output_onclick_glafqubekximcwdrbtqs(9)"
#     onmouseover="_output_onmouseover_glafqubekximcwdrbtqs(9, this);">لن</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.1171321053673995); border-radius: 3px; padding: 0px" id="_tp_glafqubekximcwdrbtqs_output_10_name"
#     onclick="_output_onclick_glafqubekximcwdrbtqs(10)"
#     onmouseover="_output_onmouseover_glafqubekximcwdrbtqs(10, this);">نكون</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.030421865715983164); border-radius: 3px; padding: 0px" id="_tp_glafqubekximcwdrbtqs_output_11_name"
#     onclick="_output_onclick_glafqubekximcwdrbtqs(11)"
#     onmouseover="_output_onmouseover_glafqubekximcwdrbtqs(11, this);">أحياء</div>
# <div style="display: inline; border-bottom: none; background: rgba(30.0, 136.0, 229.0, 0.4087938205585264); border-radius: 3px; padding: 0px" id="_tp_glafqubekximcwdrbtqs_output_12_name"
#     onclick="_output_onclick_glafqubekximcwdrbtqs(12)"
#     onmouseover="_output_onmouseover_glafqubekximcwdrbtqs(12, this);">مرة</div>
# <div style="display: inline; border-bottom: none; background: rgba(255.0, 13.0, 87.0, 0.8265795206971679); border-radius: 3px; padding: 0px" id="_tp_glafqubekximcwdrbtqs_output_13_name"
#     onclick="_output_onclick_glafqubekximcwdrbtqs(13)"
#     onmouseover="_output_onmouseover_glafqubekximcwdrbtqs(13, this);">أخرى</div><br><br><div id='_tp_glafqubekximcwdrbtqs_output_0' style='display: block';><svg width="100%" height="80px"><line x1="0" y1="33" x2="100%" y2="33" style="stroke:rgb(150,150,150);stroke-width:1" /><line x1="52.036796501612606%" y1="33" x2="52.036796501612606%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="52.036796501612606%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-6</text><line x1="39.45765757972575%" y1="33" x2="39.45765757972575%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="39.45765757972575%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-9</text><line x1="26.878518657838896%" y1="33" x2="26.878518657838896%" y2="37" style="stroke:rgb(150,150,150);stroke-width:1" /><text x="26.878518657838896%" y="27" font-size="12px" fill="rgb(120,120,120)" dominant-baseline="bottom" text-anchor="middle">-12</text><line x1="14
